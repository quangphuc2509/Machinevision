# %% [markdown]
# <a href="https://colab.research.google.com/github/quangphuc2509/Machinevision/blob/main/facetrain2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
import tensorflow as tf
import pathlib
import numpy as np
import matplotlib.pyplot as plt
from keras import layers
import os
from PIL import Image
import matplotlib.pyplot as plt
from keras import layers, models
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Rescaling
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, Callback
from IPython.display import clear_output

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
#
def ResNet34(shape = (300, 300, 3), classes = 2):
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    # Step 2 (Initial Conv layer along with maxPool)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 64
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size*2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)
    # Step 4 End Dense Network
    x = tf.keras.layers.AveragePooling2D((2,2), padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(classes, activation = 'softmax')(x)
    model = tf.keras.models.Model(inputs = x_input, outputs = x, name = "ResNet34")
    return model

# %%
model = ResNet34()
model.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 306, 306, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 153, 153, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 153, 153, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 153, 153, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 77, 77, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 77, 77, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 77, 77, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 77, 77, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 77, 77, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 77, 77, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 77, 77, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 77, 77, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 77, 77, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 77, 77, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 77, 77, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 77, 77, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 77, 77, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 77, 77, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 77, 77, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 77, 77, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 77, 77, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 77, 77, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 77, 77, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 77, 77, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 77, 77, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 77, 77, 64)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 39, 39, 128)  73856       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 39, 39, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 39, 39, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 39, 39, 128)  147584      ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 39, 39, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 39, 39, 128)  8320        ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 39, 39, 128)  0           ['batch_normalization_8[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  activation_8 (Activation)      (None, 39, 39, 128)  0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 39, 39, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 39, 39, 128)  512        ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 39, 39, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 39, 39, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 39, 39, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 39, 39, 128)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 39, 39, 128)  0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 39, 39, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 39, 39, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 39, 39, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 39, 39, 128)  147584      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 39, 39, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 39, 39, 128)  0           ['batch_normalization_12[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 39, 39, 128)  0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 39, 39, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 39, 39, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 39, 39, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 39, 39, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 39, 39, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 39, 39, 128)  0           ['batch_normalization_14[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 39, 39, 128)  0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 20, 20, 256)  295168      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 20, 20, 256)  33024       ['activation_14[0][0]']
#
#  add_7 (Add)                    (None, 20, 20, 256)  0           ['batch_normalization_16[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  activation_16 (Activation)     (None, 20, 20, 256)  0           ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 20, 20, 256)  0           ['batch_normalization_18[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 20, 20, 256)  0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 20, 20, 256)  0           ['batch_normalization_20[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 20, 20, 256)  0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 20, 20, 256)  0           ['batch_normalization_22[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 20, 20, 256)  0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 20, 20, 256)  0           ['batch_normalization_24[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 20, 20, 256)  0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 20, 20, 256)  0           ['batch_normalization_26[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 20, 20, 256)  0           ['add_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 10, 10, 512)  1180160     ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 10, 10, 512)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 10, 10, 512)  2359808     ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 10, 10, 512)  131584      ['activation_26[0][0]']
#
#  add_13 (Add)                   (None, 10, 10, 512)  0           ['batch_normalization_28[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  activation_28 (Activation)     (None, 10, 10, 512)  0           ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 10, 10, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 10, 10, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 10, 10, 512)  2359808     ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_33[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 10, 10, 512)  0           ['batch_normalization_30[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 10, 10, 512)  0           ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 10, 10, 512)  2359808     ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 10, 10, 512)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 10, 10, 512)  2359808     ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_35[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 10, 10, 512)  0           ['batch_normalization_32[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 10, 10, 512)  0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 5, 5, 512)   0           ['activation_32[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 12800)        0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 512)          6554112     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 2)            1026        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 27,861,762
# Trainable params: 27,846,530
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
# Load Dataset

dataset_url = r'/content/drive/MyDrive/xla/facedata2'
data_dir = pathlib.Path(dataset_url)

batch_size = 37
img_height = 300
img_width = 300

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split = 0.2,
  subset = "training",
  seed = 37,
  image_size = (img_height, img_width),
  batch_size = batch_size,
  color_mode="rgb")

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split = 0.2,
  subset = "validation",
  seed = 37,
  image_size = (img_height, img_width),
  batch_size = batch_size,
  color_mode="rgb")
# Out:
# Found 1413 files belonging to 2 classes.
# Using 1131 files for training.
# Found 1413 files belonging to 2 classes.
# Using 282 files for validation.

# %%
classes = train_ds.class_names
print(classes)
# Out:
# ['Phuc', 'Unkown']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(classes[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (37, 300, 300, 3)
# (37,)

# %%
class DisplayCallback(Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait = True)

callbacks = [DisplayCallback(),
            EarlyStopping(patience = 11, verbose = 1),
            ReduceLROnPlateau(patience = 3, verbose = 1),
            ModelCheckpoint('/content/drive/MyDrive/xla/face6.h5', verbose = 1, save_best_only = True)]

# %%
model.compile(optimizer = 'adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics = ['accuracy'])

# %%
history = model.fit(
          train_ds,
          validation_data = val_ds,
          epochs = 100,
          callbacks = callbacks
        )
# Out:
# Epoch 30: val_loss did not improve from 0.00002
# 31/31 [==============================] - 15s 454ms/step - loss: 8.4376e-05 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9965 - lr: 1.0000e-08
# Epoch 30: early stopping

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["loss"])
plt.title("Accuray of model")

plt.ylabel("Accuracy")
plt.xlabel("Epoch")

plt.legend(["Accuracy", "Loss"], loc = "lower right")

# %%
# Đánh giá độ chính xác của mô hình
Score=model.evaluate(val_ds,verbose=0)
print('Loss', Score[0])
print('Accuracy', Score[1])
# Out:
# Loss 0.019890399649739265
# Accuracy 0.9964538812637329

# %%
for images, labels in val_ds.take(1):

  plt.imshow(images[1].numpy().astype("uint8"))
  plt.title(classes[labels[1]])
  plt.axis("off")

  img = np.expand_dims(images[1], axis = 0)

  print('Predict:',classes[np.argmax(model.predict(img))])
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Predict: Unkown
